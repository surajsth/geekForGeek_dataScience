# %%
import pandas as pd

df1 = pd.DataFrame({
    "Name": ["Suraj", "Sanish","Dikhsya","Monica"],
    "Age": [25, 24, 24, 25],
    'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
    "Qualification": ["Data scientist","Business Analyst", "Communication Strategies", "Information Technology"]
}, index=[0, 1, 2, 3])

df2 = pd.DataFrame({'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}, index=[4, 5, 6, 7])

# %%
frames = [df1, df2]

df = pd.concat(frames)
df
# Out:
#       Name  Age    Address             Qualification
# 0    Suraj   25     Nagpur            Data scientist
# 1   Sanish   24     Kanpur          Business Analyst
# 2  Dikhsya   24  Allahabad  Communication Strategies
# 3   Monica   25    Kannuaj    Information Technology
# 4     Abhi   17     Nagpur                     Btech
# 5   Ayushi   14     Kanpur                       B.A
# 6   Dhiraj   12  Allahabad                      Bcom
# 7   Hitesh   52    Kannuaj                    B.hons

# %%
import pandas as pd

df3 = pd.DataFrame({
    "Name": ["Suraj", "Sanish","Dikhsya","Monica"],
    "Age": [25, 24, 24, 25],
    'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
    "Qualification": ["Data scientist","Business Analyst", "Communication Strategies", "Information Technology"]
}, index=[0, 1, 2, 3])

df4 = pd.DataFrame({'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}, index=[2, 4, 1, 5])

# %%
# using join
df_inner_join = pd.concat([df3, df4], axis=1, join='inner')
df_inner_join
# Out:
#       Name  Age    Address             Qualification    Name  Age    Address  \
# 1   Sanish   24     Kanpur          Business Analyst  Dhiraj   12  Allahabad
# 2  Dikhsya   24  Allahabad  Communication Strategies    Abhi   17     Nagpur
#
#   Qualification
# 1          Bcom
# 2         Btech

# %%
# outer join
df_outer_join = pd.concat([df3, df4], axis=1, sort=False)
df_outer_join
# Out:
#       Name   Age    Address             Qualification    Name   Age  \
# 0    Suraj  25.0     Nagpur            Data scientist     NaN   NaN
# 1   Sanish  24.0     Kanpur          Business Analyst  Dhiraj  12.0
# 2  Dikhsya  24.0  Allahabad  Communication Strategies    Abhi  17.0
# 3   Monica  25.0    Kannuaj    Information Technology     NaN   NaN
# 4      NaN   NaN        NaN                       NaN  Ayushi  14.0
# 5      NaN   NaN        NaN                       NaN  Hitesh  52.0
#
#      Address Qualification
# 0        NaN           NaN
# 1  Allahabad          Bcom
# 2     Nagpur         Btech
# 3        NaN           NaN
# 4     Kanpur           B.A
# 5    Kannuaj        B.hons

# %%
# Concatenating DataFrames by Ignoring Indexes
import pandas as pd 
  
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd'],
        'Mobile No': [97, 91, 58, 76]} 

data2 = {'Name':['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'], 
        'Age':[22, 32, 12, 52], 
        'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons'],
        'Salary':[1000, 2000, 3000, 4000]} 
  
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
  
df1 = pd.DataFrame(data2, index=[2, 3, 6, 7])

# %%
res = pd.concat([df, df1], ignore_index=True)
res
# Out:
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0     NaN
# 3    Anuj   32    Kannuaj           Phd       76.0     NaN
# 4  Gaurav   22  Allahabad           MCA        NaN  1000.0
# 5    Anuj   32    Kannuaj           Phd        NaN  2000.0
# 6  Dhiraj   12  Allahabad          Bcom        NaN  3000.0
# 7  Hitesh   52    Kannuaj        B.hons        NaN  4000.0

# %%
# Concatenating DataFrame with group keys :
frames = [df, df1 ]

res = pd.concat(frames, keys=['x', 'y'])
res
# Out:
#        Name  Age    Address Qualification  Mobile No  Salary
# x 0     Jai   27     Nagpur           Msc       97.0     NaN
#   1  Princi   24     Kanpur            MA       91.0     NaN
#   2  Gaurav   22  Allahabad           MCA       58.0     NaN
#   3    Anuj   32    Kannuaj           Phd       76.0     NaN
# y 2  Gaurav   22  Allahabad           MCA        NaN  1000.0
#   3    Anuj   32    Kannuaj           Phd        NaN  2000.0
#   6  Dhiraj   12  Allahabad          Bcom        NaN  3000.0
#   7  Hitesh   52    Kannuaj        B.hons        NaN  4000.0

# %%
# Concatenating Mixed DataFrames and Series
import pandas as pd

data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}

df = pd.DataFrame(data1,index=[0, 1, 2, 3])

s1 = pd.Series([1000, 2000, 3000, 4000], name='Salary')

# %%
res = pd.concat([df, s1], axis=1)
res
# Out:
#      Name  Age    Address Qualification  Salary
# 0     Jai   27     Nagpur           Msc    1000
# 1  Princi   24     Kanpur            MA    2000
# 2  Gaurav   22  Allahabad           MCA    3000
# 3    Anuj   32    Kannuaj           Phd    4000

# %%
# Merging DataFrame
# Merging DataFrames Using One Key
import pandas as pd

data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],}

data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df = pd.merge(df1, df2, on='key')
df
# Out:
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
# Merging DataFrames Using Multiple Keys
import pandas as pd

data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],}

data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}

df2 = pd.DataFrame(data1)

df3 = pd.DataFrame(data2)

# %%
res1 = pd.merge(df2, df3, on=['key', 'key1'])
res1
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
# Merging DataFrames Using the how Argument
res = pd.merge(df2, df3, how='left', on=['key', 'key1'])
res
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K1   K1  Princi   24        NaN           NaN
# 2  K2   K0  Gaurav   22  Allahabad          Bcom
# 3  K3   K1    Anuj   32        NaN           NaN

# %%
res = pd.merge(df2, df3, how='right', on=['key', 'key1'])
res
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K0     NaN   NaN     Kanpur           B.A
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
# outer
res = pd.merge(df2, df3, how='outer', on=['key', 'key1'])
res
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K0     NaN   NaN     Kanpur           B.A
# 2  K1   K1  Princi  24.0        NaN           NaN
# 3  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 4  K3   K0     NaN   NaN    Kannuaj        B.hons
# 5  K3   K1    Anuj  32.0        NaN           NaN

# %%
res = pd.merge(df2, df3, how='inner', on=['key', 'key1'])
res
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
# Joining DataFrame
# Joining DataFrames Using .join()
import pandas as pd


data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32]}

data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']}

df = pd.DataFrame(data1,index=['K0', 'K1', 'K2', 'K3'])

df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])


print(df, "\n\n", df1)
# Out:
#       Name  Age
# K0     Jai   27
# K1  Princi   24
# K2  Gaurav   22
# K3    Anuj   32
#
#        Address Qualification
# K0  Allahabad           MCA
# K2    Kannuaj           Phd
# K3  Allahabad          Bcom
# K4    Kannuaj        B.hons

# %%
res = df.join(df1)
res
# Out:
#       Name  Age    Address Qualification
# K0     Jai   27  Allahabad           MCA
# K1  Princi   24        NaN           NaN
# K2  Gaurav   22    Kannuaj           Phd
# K3    Anuj   32  Allahabad          Bcom

# %%
import pandas as pd

data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Key':['K0', 'K1', 'K2', 'K3']}

data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']}

df = pd.DataFrame(data1)

df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])


print(df, "\n\n", df1)
# Out:
#      Name  Age Key
# 0     Jai   27  K0
# 1  Princi   24  K1
# 2  Gaurav   22  K2
# 3    Anuj   32  K3
#
#        Address Qualification
# K0  Allahabad           MCA
# K2    Kannuaj           Phd
# K3  Allahabad          Bcom
# K4    Kannuaj        B.hons

# %%
# Joining DataFrames Using the "on" Argument
res2 = df.join(df1, on='Key')
res2
# Out:
#      Name  Age Key    Address Qualification
# 0     Jai   27  K0  Allahabad           MCA
# 1  Princi   24  K1        NaN           NaN
# 2  Gaurav   22  K2    Kannuaj           Phd
# 3    Anuj   32  K3  Allahabad          Bcom

# %%
# Joining DataFrames with Different Index Levels (Multi-Index)
import pandas as pd

data1 = {'Name':['Jai', 'Princi', 'Gaurav'],
        'Age':[27, 24, 22]}

data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kanpur'],
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']}

df = pd.DataFrame(data1, index=pd.Index(['K0', 'K1', 'K2'], name='key'))

index = pd.MultiIndex.from_tuples([('K0', 'Y0'), ('K1', 'Y1'),
                                   ('K2', 'Y2'), ('K2', 'Y3')],
                                   names=['key', 'Y'])

df1 = pd.DataFrame(data2, index= index)


print(df, "\n\n", df1)
# Out:
#        Name  Age
# key
# K0      Jai   27
# K1   Princi   24
# K2   Gaurav   22
#
#            Address Qualification
# key Y
# K0  Y0  Allahabad           MCA
# K1  Y1    Kannuaj           Phd
# K2  Y2  Allahabad          Bcom
#     Y3     Kanpur        B.hons

# %%
result = df.join(df1, how='inner')

result
# Out:
#           Name  Age    Address Qualification
# key Y
# K0  Y0     Jai   27  Allahabad           MCA
# K1  Y1  Princi   24    Kannuaj           Phd
# K2  Y2  Gaurav   22  Allahabad          Bcom
#     Y3  Gaurav   22     Kanpur        B.hons
